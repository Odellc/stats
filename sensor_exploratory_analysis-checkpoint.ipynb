# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv("Sensor Data-567.csv", low_memory=False)

df.head()
# Out:
#    Unnamed: 0   result table                     _time     _value  \
# 0         NaN  _result     0  2022-09-28T08:02:34.716Z   66.33468
# 1         NaN  _result     0  2022-09-28T08:02:43.524Z  66.374115
# 2         NaN  _result     0  2022-09-28T08:02:58.869Z   66.56219
# 3         NaN  _result     0  2022-09-28T08:03:13.908Z   65.69826
# 4         NaN  _result     0  2022-09-28T08:03:28.934Z   65.11304
#
#            UID Units _field       _measurement
# 0  ST1-AR2-UN1     %  Value  Relative Humidity
# 1  ST1-AR2-UN1     %  Value  Relative Humidity
# 2  ST1-AR2-UN1     %  Value  Relative Humidity
# 3  ST1-AR2-UN1     %  Value  Relative Humidity
# 4  ST1-AR2-UN1     %  Value  Relative Humidity

# %%
df.shape
# Out:
# (5538387, 9)

# %%
df.tail()
# Out:
#          Unnamed: 0   result table                     _time     _value  \
# 5538382         NaN  _result   763  2022-09-30T07:55:26.934Z  22.589565
# 5538383         NaN  _result   763   2022-09-30T07:56:28.01Z  22.633001
# 5538384         NaN  _result   763  2022-09-30T07:58:30.277Z  22.674356
# 5538385         NaN  _result   763  2022-09-30T08:01:02.148Z  22.662308
# 5538386         NaN  _result   763  2022-09-30T08:02:04.198Z   22.64996
#
#                   UID Units _field     _measurement
# 5538382  ST1-AR2-UN99    °C  Value  Air Temperature
# 5538383  ST1-AR2-UN99    °C  Value  Air Temperature
# 5538384  ST1-AR2-UN99    °C  Value  Air Temperature
# 5538385  ST1-AR2-UN99    °C  Value  Air Temperature
# 5538386  ST1-AR2-UN99    °C  Value  Air Temperature

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5538387 entries, 0 to 5538386
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    float64
#  1   result        object
#  2   table         object
#  3   _time         object
#  4   _value        object
#  5   UID           object
#  6   Units         object
#  7   _field        object
#  8   _measurement  object
# dtypes: float64(1), object(8)
# memory usage: 380.3+ MB

# %%
#df["_time"].unique()
df["_time_formatted"] = df["_time"].str[:-5].str.split("T")

print(df["_time_formatted"].str.split("T"))

df[["time_formatted","Seconds"]] = pd.DataFrame(df._time_formatted.tolist())

df = df.drop(["_time_formatted"], axis=1)

#df["time_formatted"] = pd.to_datetime(df["time_formatted"])

df.head()
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#            ..
# 5538382   NaN
# 5538383   NaN
# 5538384   NaN
# 5538385   NaN
# 5538386   NaN
# Name: _time_formatted, Length: 5538387, dtype: float64
#    Unnamed: 0   result table                     _time     _value  \
# 0         NaN  _result     0  2022-09-28T08:02:34.716Z   66.33468
# 1         NaN  _result     0  2022-09-28T08:02:43.524Z  66.374115
# 2         NaN  _result     0  2022-09-28T08:02:58.869Z   66.56219
# 3         NaN  _result     0  2022-09-28T08:03:13.908Z   65.69826
# 4         NaN  _result     0  2022-09-28T08:03:28.934Z   65.11304
#
#            UID Units _field       _measurement time_formatted  \
# 0  ST1-AR2-UN1     %  Value  Relative Humidity     2022-09-28
# 1  ST1-AR2-UN1     %  Value  Relative Humidity     2022-09-28
# 2  ST1-AR2-UN1     %  Value  Relative Humidity     2022-09-28
# 3  ST1-AR2-UN1     %  Value  Relative Humidity     2022-09-28
# 4  ST1-AR2-UN1     %  Value  Relative Humidity     2022-09-28
#
#   (time_formatted, Seconds)   Seconds
# 0    [2022-09-28, 08:02:34]  08:02:34
# 1    [2022-09-28, 08:02:43]  08:02:43
# 2    [2022-09-28, 08:02:58]  08:02:58
# 3    [2022-09-28, 08:03:13]  08:03:13
# 4    [2022-09-28, 08:03:28]  08:03:28

# %%
df.columns
# Out:
# Index([                 'Unnamed: 0',                      'result',
#                              'table',                       '_time',
#                             '_value',                         'UID',
#                              'Units',                      '_field',
#                       '_measurement',              'time_formatted',
#        ('time_formatted', 'Seconds'),                     'Seconds'],
#       dtype='object')

# %%
df["time_formatted"].unique()
# Out:
# array(['2022-09-28', '2022-09-29', '2022-09-30', ''], dtype=object)

# %%
df["UID"].unique()
# Out:
# array(['ST1-AR2-UN1', 'ST1-AR2-UN10', 'ST1-AR2-UN100', 'ST1-AR2-UN101',
#        'ST1-AR2-UN102', 'ST1-AR2-UN103', 'ST1-AR2-UN104', 'ST1-AR2-UN105',
#        'ST1-AR2-UN106', 'ST1-AR2-UN107', 'ST1-AR2-UN108', 'ST1-AR2-UN109',
#        'ST1-AR2-UN11', 'ST1-AR2-UN110', 'ST1-AR2-UN111', 'ST1-AR2-UN112',
#        'ST1-AR2-UN113', 'ST1-AR2-UN114', 'ST1-AR2-UN115', 'ST1-AR2-UN116',
#        'ST1-AR2-UN117', 'ST1-AR2-UN118', 'ST1-AR2-UN119', 'ST1-AR2-UN12',
#        'ST1-AR2-UN120', 'ST1-AR2-UN121', 'ST1-AR2-UN122', 'ST1-AR2-UN123',
#        'ST1-AR2-UN124', 'ST1-AR2-UN125', 'ST1-AR2-UN126', 'ST1-AR2-UN127',
#        'ST1-AR2-UN128', 'ST1-AR2-UN129', 'ST1-AR2-UN13', 'ST1-AR2-UN130',
#        'ST1-AR2-UN131', 'ST1-AR2-UN132', 'ST1-AR2-UN133', 'ST1-AR2-UN134',
#        'ST1-AR2-UN135', 'UID', 'ST1-AR2-UN136', 'ST1-AR2-UN137',
#        'ST1-AR2-UN138', 'ST1-AR2-UN139', 'ST1-AR2-UN14', 'ST1-AR2-UN140',
#        'ST1-AR2-UN141', 'ST1-AR2-UN142', 'ST1-AR2-UN143', 'ST1-AR2-UN144',
#        'ST1-AR2-UN145', 'ST1-AR2-UN147', 'ST1-AR2-UN148', 'ST1-AR2-UN149',
#        'ST1-AR2-UN15', 'ST1-AR2-UN150', 'ST1-AR2-UN151', 'ST1-AR2-UN152',
#        'ST1-AR2-UN154', 'ST1-AR2-UN156', 'ST1-AR2-UN158', 'ST1-AR2-UN16',
#        'ST1-AR2-UN160', 'ST1-AR2-UN162', 'ST1-AR2-UN164.1',
#        'ST1-AR2-UN164.2', 'ST1-AR2-UN164.3', 'ST1-AR2-UN164.4',
#        'ST1-AR2-UN164.5', 'ST1-AR2-UN164.6', 'ST1-AR2-UN164.7',
#        'ST1-AR2-UN165', 'ST1-AR2-UN166', 'ST1-AR2-UN167', 'ST1-AR2-UN168',
#        'ST1-AR2-UN169', 'ST1-AR2-UN17', 'ST1-AR2-UN170', 'ST1-AR2-UN171',
#        'ST1-AR2-UN172', 'ST1-AR2-UN173', 'ST1-AR2-UN174', 'ST1-AR2-UN175',
#        'ST1-AR2-UN176', 'ST1-AR2-UN177', 'ST1-AR2-UN178', 'ST1-AR2-UN179',
#        'ST1-AR2-UN180', 'ST1-AR2-UN181', 'ST1-AR2-UN182', 'ST1-AR2-UN183',
#        'ST1-AR2-UN184', 'ST1-AR2-UN185', 'ST1-AR2-UN186.1',
#        'ST1-AR2-UN186.2', 'ST1-AR2-UN186.3', 'ST1-AR2-UN186.4',
#        'ST1-AR2-UN186.5', 'ST1-AR2-UN186.6', 'ST1-AR2-UN186.7',
#        'ST1-AR2-UN187', 'ST1-AR2-UN188', 'ST1-AR2-UN189.1',
#        'ST1-AR2-UN189.2', 'ST1-AR2-UN189.3', 'ST1-AR2-UN189.4',
#        'ST1-AR2-UN189.5', 'ST1-AR2-UN189.6', 'ST1-AR2-UN189.7',
#        'ST1-AR2-UN190.1', 'ST1-AR2-UN190.2', 'ST1-AR2-UN190.3',
#        'ST1-AR2-UN190.4', 'ST1-AR2-UN190.5', 'ST1-AR2-UN190.6',
#        'ST1-AR2-UN190.7', 'ST1-AR2-UN191.1', 'ST1-AR2-UN191.2',
#        'ST1-AR2-UN191.3', 'ST1-AR2-UN191.4', 'ST1-AR2-UN191.5',
#        'ST1-AR2-UN191.6', 'ST1-AR2-UN191.7', 'ST1-AR2-UN192.1',
#        'ST1-AR2-UN192.2', 'ST1-AR2-UN192.3', 'ST1-AR2-UN192.4',
#        'ST1-AR2-UN192.5', 'ST1-AR2-UN192.6', 'ST1-AR2-UN192.7',
#        'ST1-AR2-UN193.1', 'ST1-AR2-UN193.2', 'ST1-AR2-UN193.3',
#        'ST1-AR2-UN193.4', 'ST1-AR2-UN193.5', 'ST1-AR2-UN193.6',
#        'ST1-AR2-UN193.7', 'ST1-AR2-UN194.1', 'ST1-AR2-UN194.2',
#        'ST1-AR2-UN194.3', 'ST1-AR2-UN194.4', 'ST1-AR2-UN194.5',
#        'ST1-AR2-UN194.6', 'ST1-AR2-UN194.7', 'ST1-AR2-UN195',
#        'ST1-AR2-UN196', 'ST1-AR2-UN199', 'ST1-AR2-UN2', 'ST1-AR2-UN20',
#        'ST1-AR2-UN202', 'ST1-AR2-UN203', 'ST1-AR2-UN206', 'ST1-AR2-UN207',
#        'ST1-AR2-UN21', 'ST1-AR2-UN210', 'ST1-AR2-UN213', 'ST1-AR2-UN214',
#        'ST1-AR2-UN217', 'ST1-AR2-UN218', 'ST1-AR2-UN22',
#        'ST1-AR2-UN221.1', 'ST1-AR2-UN221.2', 'ST1-AR2-UN221.3',
#        'ST1-AR2-UN221.4', 'ST1-AR2-UN221.5', 'ST1-AR2-UN221.6',
#        'ST1-AR2-UN221.7', 'ST1-AR2-UN222.1', 'ST1-AR2-UN222.2',
#        'ST1-AR2-UN222.3', 'ST1-AR2-UN222.4', 'ST1-AR2-UN222.5',
#        'ST1-AR2-UN222.6', 'ST1-AR2-UN222.7', 'ST1-AR2-UN223.1',
#        'ST1-AR2-UN223.2', 'ST1-AR2-UN223.3', 'ST1-AR2-UN223.4',
#        'ST1-AR2-UN223.5', 'ST1-AR2-UN223.6', 'ST1-AR2-UN223.7',
#        'ST1-AR2-UN224.1', 'ST1-AR2-UN224.2', 'ST1-AR2-UN224.3',
#        'ST1-AR2-UN224.4', 'ST1-AR2-UN224.5', 'ST1-AR2-UN224.6',
#        'ST1-AR2-UN224.7', 'ST1-AR2-UN225', 'ST1-AR2-UN226',
#        'ST1-AR2-UN229', 'ST1-AR2-UN23', 'ST1-AR2-UN230', 'ST1-AR2-UN24',
#        'ST1-AR2-UN241', 'ST1-AR2-UN242', 'ST1-AR2-UN245', 'ST1-AR2-UN246',
#        'ST1-AR2-UN249.1', 'ST1-AR2-UN249.2', 'ST1-AR2-UN249.3',
#        'ST1-AR2-UN249.4', 'ST1-AR2-UN249.5', 'ST1-AR2-UN249.6',
#        'ST1-AR2-UN249.7', 'ST1-AR2-UN25', 'ST1-AR2-UN250.1',
#        'ST1-AR2-UN250.2', 'ST1-AR2-UN250.3', 'ST1-AR2-UN250.4',
#        'ST1-AR2-UN250.5', 'ST1-AR2-UN250.6', 'ST1-AR2-UN250.7',
#        'ST1-AR2-UN251.1', 'ST1-AR2-UN251.2', 'ST1-AR2-UN251.3',
#        'ST1-AR2-UN251.4', 'ST1-AR2-UN251.5', 'ST1-AR2-UN251.6',
#        'ST1-AR2-UN251.7', 'ST1-AR2-UN252.1', 'ST1-AR2-UN252.2',
#        'ST1-AR2-UN252.3', 'ST1-AR2-UN252.4', 'ST1-AR2-UN252.5',
#        'ST1-AR2-UN252.6', 'ST1-AR2-UN252.7', 'ST1-AR2-UN253.1',
#        'ST1-AR2-UN253.2', 'ST1-AR2-UN253.3', 'ST1-AR2-UN253.4',
#        'ST1-AR2-UN253.5', 'ST1-AR2-UN253.6', 'ST1-AR2-UN253.7',
#        'ST1-AR2-UN254.1', 'ST1-AR2-UN254.2', 'ST1-AR2-UN254.3',
#        'ST1-AR2-UN254.4', 'ST1-AR2-UN254.5', 'ST1-AR2-UN254.6',
#        'ST1-AR2-UN254.7', 'ST1-AR2-UN255.1', 'ST1-AR2-UN255.2',
#        'ST1-AR2-UN255.3', 'ST1-AR2-UN255.4', 'ST1-AR2-UN255.5',
#        'ST1-AR2-UN255.6', 'ST1-AR2-UN255.7', 'ST1-AR2-UN256.1',
#        'ST1-AR2-UN256.2', 'ST1-AR2-UN256.3', 'ST1-AR2-UN256.4',
#        'ST1-AR2-UN256.5', 'ST1-AR2-UN256.6', 'ST1-AR2-UN256.7',
#        'ST1-AR2-UN257.1', 'ST1-AR2-UN257.2', 'ST1-AR2-UN257.3',
#        'ST1-AR2-UN257.4', 'ST1-AR2-UN257.5', 'ST1-AR2-UN257.6',
#        'ST1-AR2-UN257.7', 'ST1-AR2-UN258.1', 'ST1-AR2-UN258.2',
#        'ST1-AR2-UN258.3', 'ST1-AR2-UN258.4', 'ST1-AR2-UN258.5',
#        'ST1-AR2-UN258.6', 'ST1-AR2-UN258.7', 'ST1-AR2-UN259.1',
#        'ST1-AR2-UN259.2', 'ST1-AR2-UN259.3', 'ST1-AR2-UN259.4',
#        'ST1-AR2-UN259.5', 'ST1-AR2-UN259.6', 'ST1-AR2-UN259.7',
#        'ST1-AR2-UN26', 'ST1-AR2-UN260.1', 'ST1-AR2-UN260.2',
#        'ST1-AR2-UN260.3', 'ST1-AR2-UN260.4', 'ST1-AR2-UN260.5',
#        'ST1-AR2-UN260.6', 'ST1-AR2-UN260.7', 'ST1-AR2-UN261',
#        'ST1-AR2-UN27', 'ST1-AR2-UN28', 'ST1-AR2-UN29', 'ST1-AR2-UN3',
#        'ST1-AR2-UN30', 'ST1-AR2-UN31', 'ST1-AR2-UN32', 'ST1-AR2-UN33',
#        'ST1-AR2-UN34', 'ST1-AR2-UN35', 'ST1-AR2-UN36', 'ST1-AR2-UN37',
#        'ST1-AR2-UN38', 'ST1-AR2-UN39', 'ST1-AR2-UN4', 'ST1-AR2-UN40',
#        'ST1-AR2-UN41', 'ST1-AR2-UN42', 'ST1-AR2-UN43', 'ST1-AR2-UN44',
#        'ST1-AR2-UN45', 'ST1-AR2-UN46', 'ST1-AR2-UN47', 'ST1-AR2-UN48',
#        'ST1-AR2-UN5', 'ST1-AR2-UN50', 'ST1-AR2-UN51', 'ST1-AR2-UN52',
#        'ST1-AR2-UN54', 'ST1-AR2-UN55', 'ST1-AR2-UN56', 'ST1-AR2-UN57',
#        'ST1-AR2-UN58', 'ST1-AR2-UN59', 'ST1-AR2-UN6', 'ST1-AR2-UN60',
#        'ST1-AR2-UN62', 'ST1-AR2-UN63', 'ST1-AR2-UN64', 'ST1-AR2-UN65',
#        'ST1-AR2-UN66', 'ST1-AR2-UN67', 'ST1-AR2-UN68', 'ST1-AR2-UN69',
#        'ST1-AR2-UN7', 'ST1-AR2-UN70', 'ST1-AR2-UN71', 'ST1-AR2-UN72',
#        'ST1-AR2-UN73', 'ST1-AR2-UN74', 'ST1-AR2-UN76', 'ST1-AR2-UN77',
#        'ST1-AR2-UN78', 'ST1-AR2-UN79', 'ST1-AR2-UN8', 'ST1-AR2-UN80',
#        'ST1-AR2-UN81', 'ST1-AR2-UN82', 'ST1-AR2-UN83', 'ST1-AR2-UN84',
#        'ST1-AR2-UN85', 'ST1-AR2-UN86', 'ST1-AR2-UN87', 'ST1-AR2-UN88',
#        'ST1-AR2-UN89', 'ST1-AR2-UN9', 'ST1-AR2-UN90', 'ST1-AR2-UN91',
#        'ST1-AR2-UN92', 'ST1-AR2-UN93', 'ST1-AR2-UN94', 'ST1-AR2-UN95',
#        'ST1-AR2-UN96', 'ST1-AR2-UN97', 'ST1-AR2-UN98', 'ST1-AR2-UN99'],
#       dtype=object)

# %%
df["time_formatted"].value_counts()
# Out:
# 2022-09-29    2767462
# 2022-09-28    1839524
# 2022-09-30     931330
#                    71
# Name: time_formatted, dtype: int64

# %%
df[df["time_formatted"]==""]
# Out:
#          Unnamed: 0  result  table  _time  _value  UID   Units        _field  \
# 743707          NaN  result  table  _time  _value  UID  _field  _measurement
# 755228          NaN  result  table  _time  _value  UID   Units        _field
# 778269          NaN  result  table  _time  _value  UID  _field  _measurement
# 789771          NaN  result  table  _time  _value  UID   Units        _field
# 970033          NaN  result  table  _time  _value  UID  _field  _measurement
# ...             ...     ...    ...    ...     ...  ...     ...           ...
# 5218562         NaN  result  table  _time  _value  UID   Units        _field
# 5247491         NaN  result  table  _time  _value  UID  _field  _measurement
# 5259011         NaN  result  table  _time  _value  UID   Units        _field
# 5282050         NaN  result  table  _time  _value  UID  _field  _measurement
# 5316608         NaN  result  table  _time  _value  UID   Units        _field
#
#          _measurement time_formatted (time_formatted, Seconds) Seconds
# 743707            NaN                                       []    None
# 755228   _measurement                                       []    None
# 778269            NaN                                       []    None
# 789771   _measurement                                       []    None
# 970033            NaN                                       []    None
# ...               ...            ...                       ...     ...
# 5218562  _measurement                                       []    None
# 5247491           NaN                                       []    None
# 5259011  _measurement                                       []    None
# 5282050           NaN                                       []    None
# 5316608  _measurement                                       []    None
#
# [71 rows x 12 columns]

# %%
df.describe(include=object)
# Out:
#          result    table                 _time   _value              UID  \
# count   5538387  5538387               5538387  5538387          5538387
# unique        2      765               4026921  1522085              363
# top     _result      133  2022-09-28T08:27:30Z    false  ST1-AR2-UN223.1
# freq    5538316    11520                   112   735497            46076
#
#           Units   _field       _measurement
# count   5538387  5538387            3925777
# unique       14        5                 14
# top       Value    Value  Relative Humidity
# freq    1612574  3925742             668896

# %%
for var in df.columns:
    print(var)
    print(df[var].value_counts())
# Out:
# Unnamed: 0
# Series([], Name: Unnamed: 0, dtype: int64)
# result
# _result    5538316
# result          71
# Name: result, dtype: int64
# table
# 133      11520
# 218      11520
# 245      11520
# 246      11520
# 247      11520
#          ...
# 670        654
# 635        653
# 581        649
# 621        321
# table       71
# Name: table, Length: 765, dtype: int64
# _time
# 2022-09-28T08:27:30Z        112
# 2022-09-28T17:45:15Z        108
# 2022-09-29T22:17:00Z        107
# 2022-09-29T14:57:45Z        107
# 2022-09-29T15:05:00Z        106
#                            ...
# 2022-09-28T08:34:51.538Z      1
# 2022-09-28T08:35:06.54Z       1
# 2022-09-28T08:36:06.527Z      1
# 2022-09-28T08:38:06.551Z      1
# 2022-09-30T08:02:04.198Z      1
# Name: _time, Length: 4026921, dtype: int64
# _value
# false        735497
# true         646780
# 0            484493
# 55            87725
# 292           26129
#               ...
# 7.084205          1
# 7.0032907         1
# 7.033274          1
# 7.053279          1
# 20.429436         1
# Name: _value, Length: 1522085, dtype: int64
# UID
# ST1-AR2-UN223.1    46076
# ST1-AR2-UN190.1    46076
# ST1-AR2-UN250.1    46076
# ST1-AR2-UN194.1    46076
# ST1-AR2-UN193.1    46076
#                    ...
# ST1-AR2-UN55        2115
# ST1-AR2-UN29        2111
# ST1-AR2-UN52        2109
# ST1-AR2-UN48        1710
# UID                   71
# Name: UID, Length: 363, dtype: int64
# Units
# Value     1612574
# °C         812100
# %          680415
# Hz         552910
# kPa        541542
# VDC        276455
# Amps       276454
# ppm        233037
# mg/L       161182
# m          138228
# psi        138228
# mS/cm      115191
# _field         36
# Units          35
# Name: Units, dtype: int64
# _field
# Value           3925742
# Status          1382277
# pH               230297
# _measurement         36
# _field               35
# Name: _field, dtype: int64
# _measurement
# Relative Humidity              668896
# Air Temperature                639398
# Frequency                      552910
# Vapor Pressure Deficit         541542
# Voltage DC                     276455
# Electrical Current             276454
# Carbon Dioxide                 233037
# Water Temperature              172702
# Dissolved Oxygen               161182
# Depth                          138228
# Pressure                       138228
# Electrical Conductivity        115191
# Dissolved Oxygen Saturation     11519
# _measurement                       35
# Name: _measurement, dtype: int64

# %%
df_elec_cond = df.loc[df["_measurement"]=="Electrical Conductivity",]

# %%
df_elec_cond.head()

df_elec_cond.value_counts('Units')
# Out:
# Units
# mS/cm    115191
# dtype: int64

# %%
df_elec_cond.value_counts('_time')
# Out:
# _time
# 2022-09-28T08:02:24.142Z    1
# 2022-09-29T16:00:24.055Z    1
# 2022-09-29T16:02:35.545Z    1
# 2022-09-29T16:02:35.523Z    1
# 2022-09-29T16:02:24.175Z    1
#                            ..
# 2022-09-29T00:02:20.559Z    1
# 2022-09-29T00:02:20.517Z    1
# 2022-09-29T00:02:20.496Z    1
# 2022-09-29T00:02:09.117Z    1
# 2022-09-30T08:02:09.034Z    1
# Length: 115191, dtype: int64

# %%
#min(df_elec_cond["_time"])
#min(df["_time"])

max(df["_time"])
# Out:
# '_time'
